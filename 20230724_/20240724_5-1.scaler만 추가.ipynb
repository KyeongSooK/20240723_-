# %%
import torch
# 사용안하면 run all cells하다가 마지막에 리스타트 오류남.
# CPU 에서 GPU 활성 하기
if torch.cuda.is_available():
    device = torch.device("cuda") # 목적지가 cuda device에 설정된다.
    print("CUDA(GPU)를 사용합니다.")
else:
    device = torch.device("cpu")
    print("CUDA(GPU)를 사용할 수 없으므로, cpu를 사용합니다.")
# Out:
# CUDA(GPU)를 사용합니다.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# 데이터 로드
df = pd.read_csv('./encoded_data.csv')

# change_date 열을 제외한 나머지 열 선택
X = df.drop(columns=['change_date'])
y = df['change_date'].values  # 예측값

# 결측값 처리 (예: 평균값으로 대체) #@!
X.replace('-', np.nan, inplace=True)
X = X.astype(np.float32)
X.fillna(X.mean(), inplace=True)

y = y.astype(np.float32)

# train/test 데이터셋 나누기 (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=123)

# train 데이터셋의 일부를 다시 train(sub)/val 데이터셋으로 나누기 (80% sub(train), 20% val)
X_sub, X_val, y_sub, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=123)

# 스케일링 #@! 추가
scaler = StandardScaler()
X_sub = scaler.fit_transform(X_sub)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)

# Sequential 모델 생성
model = tf.keras.models.Sequential([
    tf.keras.layers.Dense(128, input_dim=X.shape[1], activation='relu'),  # 입력계층 특성 수를 자동으로 설정
    tf.keras.layers.Dense(64, activation='relu'),  # 은닉계층1
    tf.keras.layers.Dense(32, activation='relu'),  # 은닉계층2
    tf.keras.layers.Dense(16, activation='relu'),  # 은닉계층3
    tf.keras.layers.Dense(1, activation='linear')  # 출력계층 activation linear 사용
])

# 회귀를 위한 손실 함수(mean squared error)와 메트릭스(mean absolute error) 사용하여 모델 컴파일
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

# 모델 정보(요약) 확인
model.summary()

# 시드 값 설정
seed = 123
tf.random.set_seed(seed)
np.random.seed(seed)

# 모델 학습
history = model.fit(X_sub, y_sub, validation_data=(X_val, y_val), epochs=100, batch_size=100) # 수정

# 학습 결과 시각화
plt.figure(figsize=(10, 5))

# subplot 1: Mean Squared Error 손실 함수의 변화
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Mean Squared Error')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# subplot 2: Mean Absolute Error 매트릭스의 변화
plt.subplot(1, 2, 2)
plt.plot(history.history['mean_absolute_error'], label='Train MAE')
plt.plot(history.history['val_mean_absolute_error'], label='Val MAE')
plt.title('Mean Absolute Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.legend()

plt.show()

# 모델 평가 - 테스트 데이터셋 사용
loss_test, mae_test = model.evaluate(X_test, y_test)
print(f'Test Loss: {loss_test}')
print(f'Test MAE: {mae_test}')

# 모델 평가 - 검증 데이터셋 사용
loss_val, mae_val = model.evaluate(X_val, y_val)
print(f'Validation Loss: {loss_val}')
print(f'Validation MAE: {mae_val}')

# 예측값 생성
predictions = model.predict(X_val)

# 결정계수 계산
r2 = r2_score(y_val, predictions)
print(f'R2 Score: {r2}')
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_10 (Dense)            (None, 128)               37376
#
#  dense_11 (Dense)            (None, 64)                8256
#
#  dense_12 (Dense)            (None, 32)                2080
#
#  dense_13 (Dense)            (None, 16)                528
#
#  dense_14 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 48,257
# Trainable params: 48,257
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# C:\Users\user\AppData\Local\Temp\ipykernel_20560\360174590.py:10: DtypeWarning: Columns (4,5,6,7,8,9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./encoded_data.csv')
# 42/42 [==============================] - 1s 7ms/step - loss: 302.3693 - mean_absolute_error: 15.5121 - val_loss: 84.7973 - val_mean_absolute_error: 5.6810
# Epoch 2/100
# 42/42 [==============================] - 0s 3ms/step - loss: 23.7012 - mean_absolute_error: 3.1067 - val_loss: 10.1259 - val_mean_absolute_error: 1.4969
# Epoch 3/100
# 42/42 [==============================] - 0s 3ms/step - loss: 4.0272 - mean_absolute_error: 1.0152 - val_loss: 4.2023 - val_mean_absolute_error: 0.8636
# Epoch 4/100
# 42/42 [==============================] - 0s 3ms/step - loss: 1.6066 - mean_absolute_error: 0.6186 - val_loss: 2.1113 - val_mean_absolute_error: 0.6260
# Epoch 5/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.7726 - mean_absolute_error: 0.4456 - val_loss: 1.1201 - val_mean_absolute_error: 0.4808
# Epoch 6/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.4207 - mean_absolute_error: 0.3541 - val_loss: 0.6952 - val_mean_absolute_error: 0.4128
# Epoch 7/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.2444 - mean_absolute_error: 0.2957 - val_loss: 0.4406 - val_mean_absolute_error: 0.3562
# Epoch 8/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1620 - mean_absolute_error: 0.2549 - val_loss: 0.3310 - val_mean_absolute_error: 0.3096
# Epoch 9/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.1203 - mean_absolute_error: 0.2262 - val_loss: 0.2264 - val_mean_absolute_error: 0.2713
# Epoch 10/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0909 - mean_absolute_error: 0.2000 - val_loss: 0.1925 - val_mean_absolute_error: 0.2553
# Epoch 11/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0746 - mean_absolute_error: 0.1834 - val_loss: 0.1595 - val_mean_absolute_error: 0.2308
# Epoch 12/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0644 - mean_absolute_error: 0.1689 - val_loss: 0.1455 - val_mean_absolute_error: 0.2222
# Epoch 13/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0547 - mean_absolute_error: 0.1569 - val_loss: 0.1360 - val_mean_absolute_error: 0.2109
# Epoch 14/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0484 - mean_absolute_error: 0.1474 - val_loss: 0.1182 - val_mean_absolute_error: 0.1988
# Epoch 15/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0470 - mean_absolute_error: 0.1402 - val_loss: 0.1110 - val_mean_absolute_error: 0.1827
# Epoch 16/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0400 - mean_absolute_error: 0.1299 - val_loss: 0.1056 - val_mean_absolute_error: 0.1810
# Epoch 17/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.1227 - val_loss: 0.1025 - val_mean_absolute_error: 0.1770
# Epoch 18/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0347 - mean_absolute_error: 0.1169 - val_loss: 0.0986 - val_mean_absolute_error: 0.1708
# Epoch 19/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0307 - mean_absolute_error: 0.1115 - val_loss: 0.0928 - val_mean_absolute_error: 0.1594
# Epoch 20/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0277 - mean_absolute_error: 0.1039 - val_loss: 0.0937 - val_mean_absolute_error: 0.1589
# Epoch 21/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0251 - mean_absolute_error: 0.1027 - val_loss: 0.0863 - val_mean_absolute_error: 0.1517
# Epoch 22/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_absolute_error: 0.0966 - val_loss: 0.0872 - val_mean_absolute_error: 0.1462
# Epoch 23/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_absolute_error: 0.0925 - val_loss: 0.0797 - val_mean_absolute_error: 0.1419
# Epoch 24/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0217 - mean_absolute_error: 0.0897 - val_loss: 0.0855 - val_mean_absolute_error: 0.1417
# Epoch 25/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0230 - mean_absolute_error: 0.0855 - val_loss: 0.0784 - val_mean_absolute_error: 0.1353
# Epoch 26/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0198 - mean_absolute_error: 0.0830 - val_loss: 0.0771 - val_mean_absolute_error: 0.1340
# Epoch 27/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0197 - mean_absolute_error: 0.0784 - val_loss: 0.0765 - val_mean_absolute_error: 0.1300
# Epoch 28/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0205 - mean_absolute_error: 0.0772 - val_loss: 0.0763 - val_mean_absolute_error: 0.1266
# Epoch 29/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0212 - mean_absolute_error: 0.0757 - val_loss: 0.0776 - val_mean_absolute_error: 0.1294
# Epoch 30/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0201 - mean_absolute_error: 0.0760 - val_loss: 0.0721 - val_mean_absolute_error: 0.1233
# Epoch 31/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0194 - mean_absolute_error: 0.0740 - val_loss: 0.0770 - val_mean_absolute_error: 0.1285
# Epoch 32/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0703 - val_loss: 0.0785 - val_mean_absolute_error: 0.1212
# Epoch 33/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0164 - mean_absolute_error: 0.0654 - val_loss: 0.0738 - val_mean_absolute_error: 0.1197
# Epoch 34/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0162 - mean_absolute_error: 0.0659 - val_loss: 0.0728 - val_mean_absolute_error: 0.1160
# Epoch 35/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0278 - mean_absolute_error: 0.0677 - val_loss: 0.0710 - val_mean_absolute_error: 0.1203
# Epoch 36/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0114 - mean_absolute_error: 0.0609 - val_loss: 0.0710 - val_mean_absolute_error: 0.1169
# Epoch 37/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0586 - val_loss: 0.0648 - val_mean_absolute_error: 0.1040
# Epoch 38/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0535 - val_loss: 0.0681 - val_mean_absolute_error: 0.1058
# Epoch 39/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0102 - mean_absolute_error: 0.0537 - val_loss: 0.0654 - val_mean_absolute_error: 0.1078
# Epoch 40/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0528 - val_loss: 0.0695 - val_mean_absolute_error: 0.1046
# Epoch 41/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0128 - mean_absolute_error: 0.0527 - val_loss: 0.0737 - val_mean_absolute_error: 0.1097
# Epoch 42/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0157 - mean_absolute_error: 0.0637 - val_loss: 0.1003 - val_mean_absolute_error: 0.1214
# Epoch 43/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0225 - mean_absolute_error: 0.0656 - val_loss: 0.1135 - val_mean_absolute_error: 0.1181
# Epoch 44/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0201 - mean_absolute_error: 0.0589 - val_loss: 0.0712 - val_mean_absolute_error: 0.1177
# Epoch 45/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0179 - mean_absolute_error: 0.0605 - val_loss: 0.0684 - val_mean_absolute_error: 0.1095
# Epoch 46/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0189 - mean_absolute_error: 0.0605 - val_loss: 0.0683 - val_mean_absolute_error: 0.1095
# Epoch 47/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0108 - mean_absolute_error: 0.0555 - val_loss: 0.0652 - val_mean_absolute_error: 0.1124
# Epoch 48/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0077 - mean_absolute_error: 0.0509 - val_loss: 0.0626 - val_mean_absolute_error: 0.0991
# Epoch 49/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0081 - mean_absolute_error: 0.0520 - val_loss: 0.0645 - val_mean_absolute_error: 0.1029
# Epoch 50/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0121 - mean_absolute_error: 0.0497 - val_loss: 0.0664 - val_mean_absolute_error: 0.0997
# Epoch 51/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0134 - mean_absolute_error: 0.0510 - val_loss: 0.0623 - val_mean_absolute_error: 0.0915
# Epoch 52/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0263 - mean_absolute_error: 0.0626 - val_loss: 0.0649 - val_mean_absolute_error: 0.1105
# Epoch 53/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0242 - mean_absolute_error: 0.0619 - val_loss: 0.0613 - val_mean_absolute_error: 0.0929
# Epoch 54/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0151 - mean_absolute_error: 0.0538 - val_loss: 0.0604 - val_mean_absolute_error: 0.0959
# Epoch 55/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0152 - mean_absolute_error: 0.0523 - val_loss: 0.0625 - val_mean_absolute_error: 0.0938
# Epoch 56/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0126 - mean_absolute_error: 0.0504 - val_loss: 0.0641 - val_mean_absolute_error: 0.0968
# Epoch 57/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0146 - mean_absolute_error: 0.0592 - val_loss: 0.0616 - val_mean_absolute_error: 0.0954
# Epoch 58/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0167 - mean_absolute_error: 0.0565 - val_loss: 0.0634 - val_mean_absolute_error: 0.0979
# Epoch 59/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0173 - mean_absolute_error: 0.0547 - val_loss: 0.0704 - val_mean_absolute_error: 0.1113
# Epoch 60/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0173 - mean_absolute_error: 0.0577 - val_loss: 0.0654 - val_mean_absolute_error: 0.1087
# Epoch 61/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0334 - mean_absolute_error: 0.0680 - val_loss: 0.0990 - val_mean_absolute_error: 0.1494
# Epoch 62/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0779 - mean_absolute_error: 0.1196 - val_loss: 0.1290 - val_mean_absolute_error: 0.1667
# Epoch 63/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0469 - mean_absolute_error: 0.1130 - val_loss: 0.0832 - val_mean_absolute_error: 0.1232
# Epoch 64/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0367 - mean_absolute_error: 0.0858 - val_loss: 0.0748 - val_mean_absolute_error: 0.1243
# Epoch 65/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0385 - mean_absolute_error: 0.0849 - val_loss: 0.1303 - val_mean_absolute_error: 0.1264
# Epoch 66/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0399 - mean_absolute_error: 0.0920 - val_loss: 0.0627 - val_mean_absolute_error: 0.1208
# Epoch 67/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0350 - mean_absolute_error: 0.0870 - val_loss: 0.1143 - val_mean_absolute_error: 0.1131
# Epoch 68/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0424 - mean_absolute_error: 0.0773 - val_loss: 0.0838 - val_mean_absolute_error: 0.1169
# Epoch 69/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0348 - mean_absolute_error: 0.0747 - val_loss: 0.0911 - val_mean_absolute_error: 0.1005
# Epoch 70/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0315 - mean_absolute_error: 0.0671 - val_loss: 0.0754 - val_mean_absolute_error: 0.1127
# Epoch 71/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0279 - mean_absolute_error: 0.0719 - val_loss: 0.0690 - val_mean_absolute_error: 0.1314
# Epoch 72/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0331 - mean_absolute_error: 0.0813 - val_loss: 0.1348 - val_mean_absolute_error: 0.1280
# Epoch 73/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0394 - mean_absolute_error: 0.0783 - val_loss: 0.1944 - val_mean_absolute_error: 0.1230
# Epoch 74/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0802 - mean_absolute_error: 0.0947 - val_loss: 0.1311 - val_mean_absolute_error: 0.1256
# Epoch 75/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0450 - mean_absolute_error: 0.0854 - val_loss: 0.0833 - val_mean_absolute_error: 0.1322
# Epoch 76/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0471 - mean_absolute_error: 0.0951 - val_loss: 0.0990 - val_mean_absolute_error: 0.1523
# Epoch 77/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0443 - mean_absolute_error: 0.1114 - val_loss: 0.1184 - val_mean_absolute_error: 0.1470
# Epoch 78/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0506 - mean_absolute_error: 0.1051 - val_loss: 0.0927 - val_mean_absolute_error: 0.1404
# Epoch 79/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0502 - mean_absolute_error: 0.1144 - val_loss: 0.1375 - val_mean_absolute_error: 0.1556
# Epoch 80/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0833 - mean_absolute_error: 0.1342 - val_loss: 0.1321 - val_mean_absolute_error: 0.1507
# Epoch 81/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0514 - mean_absolute_error: 0.1052 - val_loss: 0.0744 - val_mean_absolute_error: 0.1386
# Epoch 82/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0280 - mean_absolute_error: 0.0808 - val_loss: 0.0671 - val_mean_absolute_error: 0.1140
# Epoch 83/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0235 - mean_absolute_error: 0.0881 - val_loss: 0.0737 - val_mean_absolute_error: 0.1237
# Epoch 84/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0265 - mean_absolute_error: 0.0848 - val_loss: 0.0597 - val_mean_absolute_error: 0.1063
# Epoch 85/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_absolute_error: 0.0759 - val_loss: 0.0585 - val_mean_absolute_error: 0.1030
# Epoch 86/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0252 - mean_absolute_error: 0.0789 - val_loss: 0.0726 - val_mean_absolute_error: 0.1211
# Epoch 87/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0449 - mean_absolute_error: 0.1058 - val_loss: 0.0901 - val_mean_absolute_error: 0.1302
# Epoch 88/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0366 - mean_absolute_error: 0.1088 - val_loss: 0.0798 - val_mean_absolute_error: 0.1412
# Epoch 89/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0304 - mean_absolute_error: 0.0946 - val_loss: 0.0698 - val_mean_absolute_error: 0.1226
# Epoch 90/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0336 - mean_absolute_error: 0.0874 - val_loss: 0.0788 - val_mean_absolute_error: 0.1121
# Epoch 91/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0368 - mean_absolute_error: 0.0892 - val_loss: 0.0619 - val_mean_absolute_error: 0.1105
# Epoch 92/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0397 - mean_absolute_error: 0.0931 - val_loss: 0.0604 - val_mean_absolute_error: 0.1117
# Epoch 93/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0479 - mean_absolute_error: 0.1087 - val_loss: 0.0923 - val_mean_absolute_error: 0.1459
# Epoch 94/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0734 - mean_absolute_error: 0.1492 - val_loss: 0.1631 - val_mean_absolute_error: 0.2117
# Epoch 95/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0753 - mean_absolute_error: 0.1429 - val_loss: 0.1108 - val_mean_absolute_error: 0.2072
# Epoch 96/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0587 - mean_absolute_error: 0.1346 - val_loss: 0.0837 - val_mean_absolute_error: 0.1432
# Epoch 97/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0349 - mean_absolute_error: 0.1011 - val_loss: 0.0844 - val_mean_absolute_error: 0.1331
# Epoch 98/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0333 - mean_absolute_error: 0.1033 - val_loss: 0.0930 - val_mean_absolute_error: 0.1461
# Epoch 99/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0316 - mean_absolute_error: 0.0874 - val_loss: 0.0981 - val_mean_absolute_error: 0.1287
# Epoch 100/100
# 42/42 [==============================] - 0s 3ms/step - loss: 0.0391 - mean_absolute_error: 0.1008 - val_loss: 0.1592 - val_mean_absolute_error: 0.1488
# 41/41 [==============================] - 0s 1ms/step - loss: 0.2232 - mean_absolute_error: 0.1523
# Test Loss: 0.2231644093990326
# Test MAE: 0.1523297280073166
# 33/33 [==============================] - 0s 1ms/step - loss: 0.1592 - mean_absolute_error: 0.1488
# Validation Loss: 0.15921588242053986
# Validation MAE: 0.14883317053318024
# 33/33 [==============================] - 0s 1ms/step
# R2 Score: 0.9910253286361694

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# 예측값 생성
predictions = model.predict(X_val)

# 결정계수 (R²) 계산
r2 = r2_score(y_val, predictions)
print(f"결정계수 (R²): {r2:.4f}")

# Mean Absolute Error (MAE) 계산
mae = mean_absolute_error(y_val, predictions)
print(f"Mean Absolute Error (MAE): {mae:.4f}")

# Mean Absolute Percentage Error (MAPE) 계산
mape = np.mean(np.abs((y_val - predictions) / y_val)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape:.4f}%")

# Root Mean Squared Error (RMSE) 계산
rmse = np.sqrt(mean_squared_error(y_val, predictions))
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# Mean Bias Deviation (MBD) 계산
mbd = np.mean(predictions - y_val)
print(f"Mean Bias Deviation (MBD): {mbd:.4f}")

# Adjusted R² 계산
n = len(y_val)  # 샘플 수
p = X_val.shape[1]  # 독립 변수 수
adjusted_r2 = 1 - (1 - r2) * (n - 1) / (n - p - 1)
print(f"Adjusted R²: {adjusted_r2:.4f}")
# Out:
# 33/33 [==============================] - 0s 1ms/step
# 결정계수 (R²): 0.9910
# Mean Absolute Error (MAE): 0.1488
# Mean Absolute Percentage Error (MAPE): 21.6542%
# Root Mean Squared Error (RMSE): 0.3990
# Mean Bias Deviation (MBD): -0.0656
# Adjusted R²: 0.9875

# %%
# 33/33 [==============================] - 0s 1ms/step
# 결정계수 (R²): 0.9999
# Mean Absolute Error (MAE): 0.0267
# Mean Absolute Percentage Error (MAPE): 21.5772%
# Root Mean Squared Error (RMSE): 0.0343
# Mean Bias Deviation (MBD): 0.0165
# Adjusted R²: 0.9999
